# %%
# !wget -r -N -c -np https://physionet.org/files/apnea-ecg/1.0.0/
# Out:
# --2024-03-26 13:10:21--  https://physionet.org/files/apnea-ecg/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]  45.63K  --.-KB/s    in 0.05s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-03-26 13:10:22 (942 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/index.html’ saved [46728]
#
# Loading robots.txt; please ignore errors.
# --2024-03-26 13:10:22--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2024-03-26 13:10:22 (13.1 MB/s) - ‘physionet.org/robots.txt’ saved [22/22]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/index.html’
#
# physionet.org/files     [ <=>                ]   1.17K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-03-26 13:10:22 (118 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/index.html’ saved [1203]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 87 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/ANNOTATORS’
#
# physionet.org/files 100%[===================>]      87  --.-KB/s    in 0s
#
# 2024-03-26 13:10:22 (38.9 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/ANNOTATORS’ saved [87/87]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 368 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/RECORDS’
#
# physionet.org/files 100%[===================>]     368  --.-KB/s    in 0s
#
# 2024-03-26 13:10:22 (201 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/RECORDS’ saved [368/368]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 28297 (28K) [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>]  27.63K  --.-KB/s    in 0.02s
#
# 2024-03-26 13:10:22 (1.48 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/SHA256SUMS.txt’ saved [28297/28297]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/a01.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3908 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01.apn’
#
# physionet.org/files 100%[===================>]   3.82K  --.-KB/s    in 0s
#
# 2024-03-26 13:10:22 (2.25 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01.apn’ saved [3908/3908]
#
# --2024-03-26 13:10:22--  https://physionet.org/files/apnea-ecg/1.0.0/a01.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5914000 (5.6M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01.dat’
#
# physionet.org/files 100%[===================>]   5.64M   627KB/s    in 9.1s
#
# 2024-03-26 13:10:31 (635 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01.dat’ saved [5914000/5914000]
#
# --2024-03-26 13:10:31--  https://physionet.org/files/apnea-ecg/1.0.0/a01.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:10:31 (36.5 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01.hea’ saved [55/55]
#
# --2024-03-26 13:10:31--  https://physionet.org/files/apnea-ecg/1.0.0/a01.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59878 (58K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01.qrs’
#
# physionet.org/files 100%[===================>]  58.47K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:10:31 (831 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01.qrs’ saved [59878/59878]
#
# --2024-03-26 13:10:31--  https://physionet.org/files/apnea-ecg/1.0.0/a01.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:10:31 (32.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01.xws’ saved [88/88]
#
# --2024-03-26 13:10:31--  https://physionet.org/files/apnea-ecg/1.0.0/a01er.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3908 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01er.apn’
#
# physionet.org/files 100%[===================>]   3.82K  --.-KB/s    in 0s
#
# 2024-03-26 13:10:31 (986 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01er.apn’ saved [3908/3908]
#
# --2024-03-26 13:10:31--  https://physionet.org/files/apnea-ecg/1.0.0/a01er.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 230 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01er.hea’
#
# physionet.org/files 100%[===================>]     230  --.-KB/s    in 0s
#
# 2024-03-26 13:10:32 (70.1 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01er.hea’ saved [230/230]
#
# --2024-03-26 13:10:32--  https://physionet.org/files/apnea-ecg/1.0.0/a01er.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59878 (58K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01er.qrs’
#
# physionet.org/files 100%[===================>]  58.47K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:10:32 (876 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01er.qrs’ saved [59878/59878]
#
# --2024-03-26 13:10:32--  https://physionet.org/files/apnea-ecg/1.0.0/a01er.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01er.xws’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2024-03-26 13:10:32 (30.4 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01er.xws’ saved [90/90]
#
# --2024-03-26 13:10:32--  https://physionet.org/files/apnea-ecg/1.0.0/a01r.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3908 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01r.apn’
#
# physionet.org/files 100%[===================>]   3.82K  --.-KB/s    in 0s
#
# 2024-03-26 13:10:32 (1.09 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01r.apn’ saved [3908/3908]
#
# --2024-03-26 13:10:32--  https://physionet.org/files/apnea-ecg/1.0.0/a01r.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23654368 (23M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01r.dat’
#
# physionet.org/files 100%[===================>]  22.56M   651KB/s    in 36s
#
# 2024-03-26 13:11:08 (646 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01r.dat’ saved [23654368/23654368]
#
# --2024-03-26 13:11:08--  https://physionet.org/files/apnea-ecg/1.0.0/a01r.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 193 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a01r.hea’
#
# physionet.org/files 100%[===================>]     193  --.-KB/s    in 0s
#
# 2024-03-26 13:11:08 (225 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a01r.hea’ saved [193/193]
#
# --2024-03-26 13:11:08--  https://physionet.org/files/apnea-ecg/1.0.0/a02.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4220 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02.apn’
#
# physionet.org/files 100%[===================>]   4.12K  --.-KB/s    in 0s
#
# 2024-03-26 13:11:08 (2.41 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02.apn’ saved [4220/4220]
#
# --2024-03-26 13:11:08--  https://physionet.org/files/apnea-ecg/1.0.0/a02.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6364000 (6.1M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02.dat’
#
# physionet.org/files 100%[===================>]   6.07M   658KB/s    in 9.5s
#
# 2024-03-26 13:11:17 (654 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02.dat’ saved [6364000/6364000]
#
# --2024-03-26 13:11:17--  https://physionet.org/files/apnea-ecg/1.0.0/a02.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:11:17 (25.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02.hea’ saved [55/55]
#
# --2024-03-26 13:11:17--  https://physionet.org/files/apnea-ecg/1.0.0/a02.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70498 (69K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02.qrs’
#
# physionet.org/files 100%[===================>]  68.85K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:11:18 (866 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02.qrs’ saved [70498/70498]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:11:18 (80.1 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02.xws’ saved [88/88]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02er.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4220 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02er.apn’
#
# physionet.org/files 100%[===================>]   4.12K  --.-KB/s    in 0s
#
# 2024-03-26 13:11:18 (1.12 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02er.apn’ saved [4220/4220]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02er.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 228 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02er.hea’
#
# physionet.org/files 100%[===================>]     228  --.-KB/s    in 0s
#
# 2024-03-26 13:11:18 (184 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02er.hea’ saved [228/228]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02er.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70498 (69K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02er.qrs’
#
# physionet.org/files 100%[===================>]  68.85K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:11:18 (905 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02er.qrs’ saved [70498/70498]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02er.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02er.xws’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2024-03-26 13:11:18 (77.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02er.xws’ saved [90/90]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02r.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4220 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02r.apn’
#
# physionet.org/files 100%[===================>]   4.12K  --.-KB/s    in 0s
#
# 2024-03-26 13:11:18 (1.90 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02r.apn’ saved [4220/4220]
#
# --2024-03-26 13:11:18--  https://physionet.org/files/apnea-ecg/1.0.0/a02r.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 25454368 (24M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02r.dat’
#
# physionet.org/files 100%[===================>]  24.27M   678KB/s    in 38s
#
# 2024-03-26 13:11:56 (663 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02r.dat’ saved [25454368/25454368]
#
# --2024-03-26 13:11:56--  https://physionet.org/files/apnea-ecg/1.0.0/a02r.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 191 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a02r.hea’
#
# physionet.org/files 100%[===================>]     191  --.-KB/s    in 0s
#
# 2024-03-26 13:11:56 (94.2 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a02r.hea’ saved [191/191]
#
# --2024-03-26 13:11:56--  https://physionet.org/files/apnea-ecg/1.0.0/a03.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4148 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03.apn’
#
# physionet.org/files 100%[===================>]   4.05K  --.-KB/s    in 0s
#
# 2024-03-26 13:11:56 (1007 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03.apn’ saved [4148/4148]
#
# --2024-03-26 13:11:56--  https://physionet.org/files/apnea-ecg/1.0.0/a03.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6270000 (6.0M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03.dat’
#
# physionet.org/files 100%[===================>]   5.98M   682KB/s    in 9.1s
#
# 2024-03-26 13:12:05 (671 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03.dat’ saved [6270000/6270000]
#
# --2024-03-26 13:12:05--  https://physionet.org/files/apnea-ecg/1.0.0/a03.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:12:05 (22.4 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03.hea’ saved [57/57]
#
# --2024-03-26 13:12:05--  https://physionet.org/files/apnea-ecg/1.0.0/a03.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68520 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03.qrs’
#
# physionet.org/files 100%[===================>]  66.91K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:12:05 (866 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03.qrs’ saved [68520/68520]
#
# --2024-03-26 13:12:05--  https://physionet.org/files/apnea-ecg/1.0.0/a03.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:12:05 (33.4 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03.xws’ saved [88/88]
#
# --2024-03-26 13:12:05--  https://physionet.org/files/apnea-ecg/1.0.0/a03er.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4148 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03er.apn’
#
# physionet.org/files 100%[===================>]   4.05K  --.-KB/s    in 0s
#
# 2024-03-26 13:12:05 (1.55 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03er.apn’ saved [4148/4148]
#
# --2024-03-26 13:12:05--  https://physionet.org/files/apnea-ecg/1.0.0/a03er.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 232 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03er.hea’
#
# physionet.org/files 100%[===================>]     232  --.-KB/s    in 0s
#
# 2024-03-26 13:12:06 (236 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03er.hea’ saved [232/232]
#
# --2024-03-26 13:12:06--  https://physionet.org/files/apnea-ecg/1.0.0/a03er.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68520 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03er.qrs’
#
# physionet.org/files 100%[===================>]  66.91K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:12:06 (856 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03er.qrs’ saved [68520/68520]
#
# --2024-03-26 13:12:06--  https://physionet.org/files/apnea-ecg/1.0.0/a03er.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03er.xws’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2024-03-26 13:12:06 (83.1 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03er.xws’ saved [90/90]
#
# --2024-03-26 13:12:06--  https://physionet.org/files/apnea-ecg/1.0.0/a03r.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4148 (4.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03r.apn’
#
# physionet.org/files 100%[===================>]   4.05K  --.-KB/s    in 0s
#
# 2024-03-26 13:12:06 (1.21 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03r.apn’ saved [4148/4148]
#
# --2024-03-26 13:12:06--  https://physionet.org/files/apnea-ecg/1.0.0/a03r.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 25078368 (24M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03r.dat’
#
# physionet.org/files 100%[===================>]  23.92M   694KB/s    in 37s
#
# 2024-03-26 13:12:43 (668 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03r.dat’ saved [25078368/25078368]
#
# --2024-03-26 13:12:43--  https://physionet.org/files/apnea-ecg/1.0.0/a03r.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 193 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a03r.hea’
#
# physionet.org/files 100%[===================>]     193  --.-KB/s    in 0s
#
# 2024-03-26 13:12:43 (87.4 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a03r.hea’ saved [193/193]
#
# --2024-03-26 13:12:43--  https://physionet.org/files/apnea-ecg/1.0.0/a04.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3932 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04.apn’
#
# physionet.org/files 100%[===================>]   3.84K  --.-KB/s    in 0s
#
# 2024-03-26 13:12:43 (1.57 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04.apn’ saved [3932/3932]
#
# --2024-03-26 13:12:43--  https://physionet.org/files/apnea-ecg/1.0.0/a04.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5960000 (5.7M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04.dat’
#
# physionet.org/files 100%[===================>]   5.68M   691KB/s    in 8.7s
#
# 2024-03-26 13:12:52 (670 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04.dat’ saved [5960000/5960000]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (19.3 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04.hea’ saved [57/57]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 62488 (61K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04.qrs’
#
# physionet.org/files 100%[===================>]  61.02K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:12:52 (915 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04.qrs’ saved [62488/62488]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (33.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04.xws’ saved [88/88]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04er.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3932 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04er.apn’
#
# physionet.org/files 100%[===================>]   3.84K  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (1.32 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04er.apn’ saved [3932/3932]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04er.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 230 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04er.hea’
#
# physionet.org/files 100%[===================>]     230  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (92.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04er.hea’ saved [230/230]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04er.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 62488 (61K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04er.qrs’
#
# physionet.org/files 100%[===================>]  61.02K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:12:52 (957 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04er.qrs’ saved [62488/62488]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04er.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04er.xws’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (37.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04er.xws’ saved [90/90]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04r.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3932 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04r.apn’
#
# physionet.org/files 100%[===================>]   3.84K  --.-KB/s    in 0s
#
# 2024-03-26 13:12:52 (1.31 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04r.apn’ saved [3932/3932]
#
# --2024-03-26 13:12:52--  https://physionet.org/files/apnea-ecg/1.0.0/a04r.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23838368 (23M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04r.dat’
#
# physionet.org/files 100%[===================>]  22.73M   660KB/s    in 35s
#
# 2024-03-26 13:13:27 (666 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04r.dat’ saved [23838368/23838368]
#
# --2024-03-26 13:13:27--  https://physionet.org/files/apnea-ecg/1.0.0/a04r.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 191 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a04r.hea’
#
# physionet.org/files 100%[===================>]     191  --.-KB/s    in 0s
#
# 2024-03-26 13:13:27 (107 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a04r.hea’ saved [191/191]
#
# --2024-03-26 13:13:27--  https://physionet.org/files/apnea-ecg/1.0.0/a05.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3628 (3.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a05.apn’
#
# physionet.org/files 100%[===================>]   3.54K  --.-KB/s    in 0s
#
# 2024-03-26 13:13:27 (1.52 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a05.apn’ saved [3628/3628]
#
# --2024-03-26 13:13:27--  https://physionet.org/files/apnea-ecg/1.0.0/a05.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5439000 (5.2M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a05.dat’
#
# physionet.org/files 100%[===================>]   5.19M   664KB/s    in 8.3s
#
# 2024-03-26 13:13:36 (640 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a05.dat’ saved [5439000/5439000]
#
# --2024-03-26 13:13:36--  https://physionet.org/files/apnea-ecg/1.0.0/a05.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a05.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:13:36 (65.3 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a05.hea’ saved [57/57]
#
# --2024-03-26 13:13:36--  https://physionet.org/files/apnea-ecg/1.0.0/a05.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57558 (56K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a05.qrs’
#
# physionet.org/files 100%[===================>]  56.21K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:13:36 (914 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a05.qrs’ saved [57558/57558]
#
# --2024-03-26 13:13:36--  https://physionet.org/files/apnea-ecg/1.0.0/a05.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a05.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:13:36 (103 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a05.xws’ saved [88/88]
#
# --2024-03-26 13:13:36--  https://physionet.org/files/apnea-ecg/1.0.0/a06.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4076 (4.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a06.apn’
#
# physionet.org/files 100%[===================>]   3.98K  --.-KB/s    in 0s
#
# 2024-03-26 13:13:36 (2.48 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a06.apn’ saved [4076/4076]
#
# --2024-03-26 13:13:36--  https://physionet.org/files/apnea-ecg/1.0.0/a06.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6116000 (5.8M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a06.dat’
#
# physionet.org/files 100%[===================>]   5.83M   672KB/s    in 9.0s
#
# 2024-03-26 13:13:45 (663 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a06.dat’ saved [6116000/6116000]
#
# --2024-03-26 13:13:45--  https://physionet.org/files/apnea-ecg/1.0.0/a06.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a06.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:13:45 (25.0 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a06.hea’ saved [57/57]
#
# --2024-03-26 13:13:45--  https://physionet.org/files/apnea-ecg/1.0.0/a06.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54578 (53K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a06.qrs’
#
# physionet.org/files 100%[===================>]  53.30K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:13:45 (964 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a06.qrs’ saved [54578/54578]
#
# --2024-03-26 13:13:45--  https://physionet.org/files/apnea-ecg/1.0.0/a06.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a06.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:13:46 (42.8 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a06.xws’ saved [88/88]
#
# --2024-03-26 13:13:46--  https://physionet.org/files/apnea-ecg/1.0.0/a07.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4084 (4.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a07.apn’
#
# physionet.org/files 100%[===================>]   3.99K  --.-KB/s    in 0s
#
# 2024-03-26 13:13:46 (1.65 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a07.apn’ saved [4084/4084]
#
# --2024-03-26 13:13:46--  https://physionet.org/files/apnea-ecg/1.0.0/a07.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6121000 (5.8M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a07.dat’
#
# physionet.org/files 100%[===================>]   5.84M   681KB/s    in 8.9s
#
# 2024-03-26 13:13:55 (672 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a07.dat’ saved [6121000/6121000]
#
# --2024-03-26 13:13:55--  https://physionet.org/files/apnea-ecg/1.0.0/a07.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a07.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:13:55 (65.6 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a07.hea’ saved [56/56]
#
# --2024-03-26 13:13:55--  https://physionet.org/files/apnea-ecg/1.0.0/a07.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74958 (73K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a07.qrs’
#
# physionet.org/files 100%[===================>]  73.20K  --.-KB/s    in 0.1s
#
# 2024-03-26 13:13:55 (524 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a07.qrs’ saved [74958/74958]
#
# --2024-03-26 13:13:55--  https://physionet.org/files/apnea-ecg/1.0.0/a07.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a07.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:13:55 (32.5 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a07.xws’ saved [88/88]
#
# --2024-03-26 13:13:55--  https://physionet.org/files/apnea-ecg/1.0.0/a08.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4004 (3.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a08.apn’
#
# physionet.org/files 100%[===================>]   3.91K  --.-KB/s    in 0s
#
# 2024-03-26 13:13:55 (1.50 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a08.apn’ saved [4004/4004]
#
# --2024-03-26 13:13:55--  https://physionet.org/files/apnea-ecg/1.0.0/a08.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6005000 (5.7M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a08.dat’
#
# physionet.org/files 100%[===================>]   5.73M   671KB/s    in 8.8s
#
# 2024-03-26 13:14:04 (669 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a08.dat’ saved [6005000/6005000]
#
# --2024-03-26 13:14:04--  https://physionet.org/files/apnea-ecg/1.0.0/a08.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a08.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:14:04 (21.3 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a08.hea’ saved [57/57]
#
# --2024-03-26 13:14:04--  https://physionet.org/files/apnea-ecg/1.0.0/a08.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 82292 (80K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a08.qrs’
#
# physionet.org/files 100%[===================>]  80.36K  --.-KB/s    in 0.09s
#
# 2024-03-26 13:14:04 (854 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a08.qrs’ saved [82292/82292]
#
# --2024-03-26 13:14:04--  https://physionet.org/files/apnea-ecg/1.0.0/a08.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a08.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:04 (31.4 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a08.xws’ saved [88/88]
#
# --2024-03-26 13:14:04--  https://physionet.org/files/apnea-ecg/1.0.0/a09.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3956 (3.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a09.apn’
#
# physionet.org/files 100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:04 (1.06 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a09.apn’ saved [3956/3956]
#
# --2024-03-26 13:14:04--  https://physionet.org/files/apnea-ecg/1.0.0/a09.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5976000 (5.7M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a09.dat’
#
# physionet.org/files 100%[===================>]   5.70M   659KB/s    in 8.8s
#
# 2024-03-26 13:14:13 (661 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a09.dat’ saved [5976000/5976000]
#
# --2024-03-26 13:14:13--  https://physionet.org/files/apnea-ecg/1.0.0/a09.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a09.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:14:13 (25.2 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a09.hea’ saved [55/55]
#
# --2024-03-26 13:14:13--  https://physionet.org/files/apnea-ecg/1.0.0/a09.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63108 (62K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a09.qrs’
#
# physionet.org/files 100%[===================>]  61.63K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:14:13 (857 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a09.qrs’ saved [63108/63108]
#
# --2024-03-26 13:14:13--  https://physionet.org/files/apnea-ecg/1.0.0/a09.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a09.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:14 (36.0 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a09.xws’ saved [88/88]
#
# --2024-03-26 13:14:14--  https://physionet.org/files/apnea-ecg/1.0.0/a10.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4132 (4.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a10.apn’
#
# physionet.org/files 100%[===================>]   4.04K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:14 (2.14 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a10.apn’ saved [4132/4132]
#
# --2024-03-26 13:14:14--  https://physionet.org/files/apnea-ecg/1.0.0/a10.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6203000 (5.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a10.dat’
#
# physionet.org/files 100%[===================>]   5.92M   655KB/s    in 9.2s
#
# 2024-03-26 13:14:23 (658 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a10.dat’ saved [6203000/6203000]
#
# --2024-03-26 13:14:23--  https://physionet.org/files/apnea-ecg/1.0.0/a10.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a10.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:14:23 (19.6 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a10.hea’ saved [56/56]
#
# --2024-03-26 13:14:23--  https://physionet.org/files/apnea-ecg/1.0.0/a10.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 64612 (63K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a10.qrs’
#
# physionet.org/files 100%[===================>]  63.10K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:14:23 (995 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a10.qrs’ saved [64612/64612]
#
# --2024-03-26 13:14:23--  https://physionet.org/files/apnea-ecg/1.0.0/a10.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a10.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:23 (38.3 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a10.xws’ saved [88/88]
#
# --2024-03-26 13:14:23--  https://physionet.org/files/apnea-ecg/1.0.0/a11.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3724 (3.6K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a11.apn’
#
# physionet.org/files 100%[===================>]   3.64K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:23 (1.41 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a11.apn’ saved [3724/3724]
#
# --2024-03-26 13:14:23--  https://physionet.org/files/apnea-ecg/1.0.0/a11.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5616000 (5.4M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a11.dat’
#
# physionet.org/files 100%[===================>]   5.36M   630KB/s    in 8.4s
#
# 2024-03-26 13:14:32 (651 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a11.dat’ saved [5616000/5616000]
#
# --2024-03-26 13:14:32--  https://physionet.org/files/apnea-ecg/1.0.0/a11.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a11.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:14:32 (26.5 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a11.hea’ saved [56/56]
#
# --2024-03-26 13:14:32--  https://physionet.org/files/apnea-ecg/1.0.0/a11.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 66392 (65K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a11.qrs’
#
# physionet.org/files 100%[===================>]  64.84K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:14:32 (938 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a11.qrs’ saved [66392/66392]
#
# --2024-03-26 13:14:32--  https://physionet.org/files/apnea-ecg/1.0.0/a11.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a11.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:32 (22.6 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a11.xws’ saved [88/88]
#
# --2024-03-26 13:14:32--  https://physionet.org/files/apnea-ecg/1.0.0/a12.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4612 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a12.apn’
#
# physionet.org/files 100%[===================>]   4.50K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:32 (1.74 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a12.apn’ saved [4612/4612]
#
# --2024-03-26 13:14:32--  https://physionet.org/files/apnea-ecg/1.0.0/a12.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6924000 (6.6M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a12.dat’
#
# physionet.org/files 100%[===================>]   6.60M   659KB/s    in 10s
#
# 2024-03-26 13:14:42 (656 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a12.dat’ saved [6924000/6924000]
#
# --2024-03-26 13:14:42--  https://physionet.org/files/apnea-ecg/1.0.0/a12.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a12.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:14:43 (74.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a12.hea’ saved [56/56]
#
# --2024-03-26 13:14:43--  https://physionet.org/files/apnea-ecg/1.0.0/a12.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 67882 (66K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a12.qrs’
#
# physionet.org/files 100%[===================>]  66.29K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:14:43 (855 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a12.qrs’ saved [67882/67882]
#
# --2024-03-26 13:14:43--  https://physionet.org/files/apnea-ecg/1.0.0/a12.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a12.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:43 (88.2 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a12.xws’ saved [88/88]
#
# --2024-03-26 13:14:43--  https://physionet.org/files/apnea-ecg/1.0.0/a13.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3956 (3.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a13.apn’
#
# physionet.org/files 100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:43 (3.05 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a13.apn’ saved [3956/3956]
#
# --2024-03-26 13:14:43--  https://physionet.org/files/apnea-ecg/1.0.0/a13.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5931000 (5.7M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a13.dat’
#
# physionet.org/files 100%[===================>]   5.66M   648KB/s    in 9.0s
#
# 2024-03-26 13:14:52 (647 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a13.dat’ saved [5931000/5931000]
#
# --2024-03-26 13:14:52--  https://physionet.org/files/apnea-ecg/1.0.0/a13.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a13.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:14:52 (25.8 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a13.hea’ saved [56/56]
#
# --2024-03-26 13:14:52--  https://physionet.org/files/apnea-ecg/1.0.0/a13.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 79586 (78K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a13.qrs’
#
# physionet.org/files 100%[===================>]  77.72K  --.-KB/s    in 0.1s
#
# 2024-03-26 13:14:52 (585 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a13.qrs’ saved [79586/79586]
#
# --2024-03-26 13:14:52--  https://physionet.org/files/apnea-ecg/1.0.0/a13.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a13.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:14:52 (40.9 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a13.xws’ saved [88/88]
#
# --2024-03-26 13:14:52--  https://physionet.org/files/apnea-ecg/1.0.0/a14.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4068 (4.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a14.apn’
#
# physionet.org/files 100%[===================>]   3.97K  --.-KB/s    in 0s
#
# 2024-03-26 13:14:52 (2.21 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a14.apn’ saved [4068/4068]
#
# --2024-03-26 13:14:52--  https://physionet.org/files/apnea-ecg/1.0.0/a14.dat
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6270000 (6.0M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a14.dat’
#
# physionet.org/files 100%[===================>]   5.98M   671KB/s    in 9.3s
#
# 2024-03-26 13:15:02 (657 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a14.dat’ saved [6270000/6270000]
#
# --2024-03-26 13:15:02--  https://physionet.org/files/apnea-ecg/1.0.0/a14.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a14.hea’
#
# physionet.org/files 100%[===================>]      56  --.-KB/s    in 0s
#
# 2024-03-26 13:15:02 (55.6 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a14.hea’ saved [56/56]
#
# --2024-03-26 13:15:02--  https://physionet.org/files/apnea-ecg/1.0.0/a14.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 58038 (57K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a14.qrs’
#
# physionet.org/files 100%[===================>]  56.68K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:15:02 (928 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a14.qrs’ saved [58038/58038]
#
# --2024-03-26 13:15:02--  https://physionet.org/files/apnea-ecg/1.0.0/a14.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a14.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:15:02 (37.8 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a14.xws’ saved [88/88]
#
# --2024-03-26 13:15:02--  https://physionet.org/files/apnea-ecg/1.0.0/a15.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4076 (4.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a15.apn’
#
# physionet.org/files 100%[===================>]   3.98K  --.-KB/s    in 0s
#
# 2024-03-26 13:15:02 (1.60 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/a15.apn’ saved [4076/4076]
#
# --2024-03-26 13:15:02--  https://physionet.org/files/apnea-ecg/1.0.0/a15.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6112000 (5.8M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/a15.dat’
#
# physionet.org/files 100%[===================>]   5.83M   650KB/s    in 9.1s
#
# ...
#
# physionet.org/files 100%[===================>]  71.33K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:25:06 (980 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x30.qrs’ saved [73038/73038]
#
# --2024-03-26 13:25:06--  https://physionet.org/files/apnea-ecg/1.0.0/x30.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x30.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:06 (37.2 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x30.xws’ saved [88/88]
#
# --2024-03-26 13:25:06--  https://physionet.org/files/apnea-ecg/1.0.0/x31.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4452 (4.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x31.apn’
#
# physionet.org/files 100%[===================>]   4.35K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:06 (1.18 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x31.apn’ saved [4452/4452]
#
# --2024-03-26 13:25:06--  https://physionet.org/files/apnea-ecg/1.0.0/x31.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6684000 (6.4M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x31.dat’
#
# physionet.org/files 100%[===================>]   6.37M   662KB/s    in 9.9s
#
# 2024-03-26 13:25:16 (659 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x31.dat’ saved [6684000/6684000]
#
# --2024-03-26 13:25:16--  https://physionet.org/files/apnea-ecg/1.0.0/x31.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x31.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:25:16 (61.1 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x31.hea’ saved [55/55]
#
# --2024-03-26 13:25:16--  https://physionet.org/files/apnea-ecg/1.0.0/x31.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68344 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x31.qrs’
#
# physionet.org/files 100%[===================>]  66.74K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:25:16 (871 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x31.qrs’ saved [68344/68344]
#
# --2024-03-26 13:25:16--  https://physionet.org/files/apnea-ecg/1.0.0/x31.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x31.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:16 (34.5 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x31.xws’ saved [88/88]
#
# --2024-03-26 13:25:16--  https://physionet.org/files/apnea-ecg/1.0.0/x32.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4300 (4.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x32.apn’
#
# physionet.org/files 100%[===================>]   4.20K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:16 (1.35 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x32.apn’ saved [4300/4300]
#
# --2024-03-26 13:25:16--  https://physionet.org/files/apnea-ecg/1.0.0/x32.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6456000 (6.2M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x32.dat’
#
# physionet.org/files 100%[===================>]   6.16M   651KB/s    in 9.6s
#
# 2024-03-26 13:25:26 (660 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x32.dat’ saved [6456000/6456000]
#
# --2024-03-26 13:25:26--  https://physionet.org/files/apnea-ecg/1.0.0/x32.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 57 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x32.hea’
#
# physionet.org/files 100%[===================>]      57  --.-KB/s    in 0s
#
# 2024-03-26 13:25:26 (27.9 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x32.hea’ saved [57/57]
#
# --2024-03-26 13:25:26--  https://physionet.org/files/apnea-ecg/1.0.0/x32.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68238 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x32.qrs’
#
# physionet.org/files 100%[===================>]  66.64K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:25:26 (856 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x32.qrs’ saved [68238/68238]
#
# --2024-03-26 13:25:26--  https://physionet.org/files/apnea-ecg/1.0.0/x32.xws
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x32.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:26 (35.8 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x32.xws’ saved [88/88]
#
# --2024-03-26 13:25:26--  https://physionet.org/files/apnea-ecg/1.0.0/x33.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3780 (3.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x33.apn’
#
# physionet.org/files 100%[===================>]   3.69K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:26 (1.69 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x33.apn’ saved [3780/3780]
#
# --2024-03-26 13:25:26--  https://physionet.org/files/apnea-ecg/1.0.0/x33.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5668000 (5.4M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x33.dat’
#
# physionet.org/files 100%[===================>]   5.41M   659KB/s    in 8.4s
#
# 2024-03-26 13:25:35 (661 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x33.dat’ saved [5668000/5668000]
#
# --2024-03-26 13:25:35--  https://physionet.org/files/apnea-ecg/1.0.0/x33.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 53 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x33.hea’
#
# physionet.org/files 100%[===================>]      53  --.-KB/s    in 0s
#
# 2024-03-26 13:25:35 (40.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x33.hea’ saved [53/53]
#
# --2024-03-26 13:25:35--  https://physionet.org/files/apnea-ecg/1.0.0/x33.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68220 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x33.qrs’
#
# physionet.org/files 100%[===================>]  66.62K  --.-KB/s    in 0.07s
#
# 2024-03-26 13:25:35 (955 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x33.qrs’ saved [68220/68220]
#
# --2024-03-26 13:25:35--  https://physionet.org/files/apnea-ecg/1.0.0/x33.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x33.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:35 (36.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x33.xws’ saved [88/88]
#
# --2024-03-26 13:25:35--  https://physionet.org/files/apnea-ecg/1.0.0/x34.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3796 (3.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x34.apn’
#
# physionet.org/files 100%[===================>]   3.71K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:35 (1013 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x34.apn’ saved [3796/3796]
#
# --2024-03-26 13:25:35--  https://physionet.org/files/apnea-ecg/1.0.0/x34.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5690000 (5.4M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x34.dat’
#
# physionet.org/files 100%[===================>]   5.43M   663KB/s    in 8.5s
#
# 2024-03-26 13:25:44 (657 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x34.dat’ saved [5690000/5690000]
#
# --2024-03-26 13:25:44--  https://physionet.org/files/apnea-ecg/1.0.0/x34.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x34.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:25:44 (29.6 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x34.hea’ saved [55/55]
#
# --2024-03-26 13:25:44--  https://physionet.org/files/apnea-ecg/1.0.0/x34.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68506 (67K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x34.qrs’
#
# physionet.org/files 100%[===================>]  66.90K  --.-KB/s    in 0.08s
#
# 2024-03-26 13:25:44 (829 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x34.qrs’ saved [68506/68506]
#
# --2024-03-26 13:25:44--  https://physionet.org/files/apnea-ecg/1.0.0/x34.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x34.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:44 (87.7 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x34.xws’ saved [88/88]
#
# --2024-03-26 13:25:44--  https://physionet.org/files/apnea-ecg/1.0.0/x35.apn
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3860 (3.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x35.apn’
#
# physionet.org/files 100%[===================>]   3.77K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:44 (1.39 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x35.apn’ saved [3860/3860]
#
# --2024-03-26 13:25:44--  https://physionet.org/files/apnea-ecg/1.0.0/x35.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5786000 (5.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x35.dat’
#
# physionet.org/files 100%[===================>]   5.52M   671KB/s    in 8.5s
#
# 2024-03-26 13:25:53 (664 KB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x35.dat’ saved [5786000/5786000]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/x35.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 55 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x35.hea’
#
# physionet.org/files 100%[===================>]      55  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (21.0 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x35.hea’ saved [55/55]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/x35.qrs
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 58202 (57K) [application/octet-stream]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x35.qrs’
#
# physionet.org/files 100%[===================>]  56.84K  --.-KB/s    in 0.06s
#
# 2024-03-26 13:25:53 (1.00 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x35.qrs’ saved [58202/58202]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/x35.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 88 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/x35.xws’
#
# physionet.org/files 100%[===================>]      88  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (92.1 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/x35.xws’ saved [88/88]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/distill.c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6712 (6.6K) [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/distill.c’
#
# physionet.org/files 100%[===================>]   6.55K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (2.03 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/distill.c’ saved [6712/6712]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/index.shtml
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3935 (3.8K) [text/html]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/index.shtml’
#
# physionet.org/files 100%[===================>]   3.84K  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (1.60 GB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/index.shtml’ saved [3935/3935]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 210 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-1’
#
# physionet.org/files 100%[===================>]     210  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (162 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-1’ saved [210/210]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18440 (18K) [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-2’
#
# physionet.org/files 100%[===================>]  18.01K  --.-KB/s    in 0.004s
#
# 2024-03-26 13:25:53 (4.14 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/summary-training-2’ saved [18440/18440]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 210 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-1’
#
# physionet.org/files 100%[===================>]     210  --.-KB/s    in 0s
#
# 2024-03-26 13:25:53 (208 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-1’ saved [210/210]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18663 (18K) [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-2’
#
# physionet.org/files 100%[===================>]  18.23K  --.-KB/s    in 0.004s
#
# 2024-03-26 13:25:53 (4.95 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-test-2’ saved [18663/18663]
#
# --2024-03-26 13:25:53--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 210 [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-1’
#
# physionet.org/files 100%[===================>]     210  --.-KB/s    in 0s
#
# 2024-03-26 13:25:54 (64.9 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-1’ saved [210/210]
#
# --2024-03-26 13:25:54--  https://physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-2
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18440 (18K) [text/plain]
# Saving to: ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-2’
#
# physionet.org/files 100%[===================>]  18.01K  --.-KB/s    in 0.004s
#
# 2024-03-26 13:25:54 (4.18 MB/s) - ‘physionet.org/files/apnea-ecg/1.0.0/challenge/template-training-2’ saved [18440/18440]
#
# FINISHED --2024-03-26 13:25:54--
# Total wall clock time: 15m 33s
# Downloaded: 424 files, 581M in 14m 59s (661 KB/s)

# %%
path ='/content/physionet.org/files/apnea-ecg/1.0.0/a01.dat'

# %%
# !pip install wfdb -qq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 1.7 MB/s eta 0:00:00

# %%
import wfdb
import pandas as pd

# record = wfdb.rdrecord('sample')

# %%
a01 = wfdb.rdsamp('/content/physionet.org/files/apnea-ecg/1.0.0/a01')

# %%
# prompt: 위의 a01 시각화해줘

import matplotlib.pyplot as plt

plt.plot(a01[0][:1000])
plt.show()

# %%
len(a01[0])
# Out:
# 2957000

# %%
sig, fields = wfdb.rdsamp('/content/physionet.org/files/apnea-ecg/1.0.0/a01',sampto = 1000)

# %%
wfdb.wrsamp('ecgrecord',fs=250,units=['mV','mV'],sig_name = ['I','II'],p_signal=sig,fmt= ['16','16'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-e82e0002cfff> in <cell line: 1>()
# ----> 1 wfdb.wrsamp('ecgrecord',fs=250,units=['mV','mV'],sig_name = ['I','II'],p_signal=sig,fmt= ['16','16'])
#
# /usr/local/lib/python3.10/dist-packages/wfdb/io/record.py in wrsamp(record_name, fs, units, sig_name, p_signal, d_signal, fmt, adc_gain, baseline, comments, base_time, base_date, base_datetime, write_dir)
#    2966     record.set_defaults()
#    2967     # Write the record files - header and associated dat
# -> 2968     record.wrsamp(write_dir=write_dir)
#    2969
#    2970
#
# /usr/local/lib/python3.10/dist-packages/wfdb/io/record.py in wrsamp(self, expanded, write_dir)
#     933         # Perform field validity and cohesion checks, and write the
#     934         # header file.
# --> 935         self.wrheader(write_dir=write_dir, expanded=expanded)
#     936         if self.n_sig > 0:
#     937             # Perform signal validity and cohesion checks, and write the
#
# /usr/local/lib/python3.10/dist-packages/wfdb/io/_header.py in wrheader(self, write_dir, expanded)
#     323
#     324         # Check the cohesion of fields used to write the header
# --> 325         self.check_field_cohesion(rec_write_fields, list(sig_write_fields))
#     326
#     327         # Write the header file using the specified fields
#
# /usr/local/lib/python3.10/dist-packages/wfdb/io/_header.py in check_field_cohesion(self, rec_write_fields, sig_write_fields)
#     477             for f in sig_write_fields:
#     478                 if len(getattr(self, f)) != self.n_sig:
# --> 479                     raise ValueError(
#     480                         "The length of field: " + f + " must match field n_sig."
#     481                     )
#
# ValueError: The length of field: sig_name must match field n_sig.

# %%
record = wfdb.rdrecord()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c45d0da7d285> in <cell line: 1>()
# ----> 1 wfdb.plot_wfdb(a01)
#
# /usr/local/lib/python3.10/dist-packages/wfdb/plot/plot.py in plot_wfdb(record, annotation, plot_sym, time_units, title, sig_style, ann_style, ecg_grids, figsize, return_fig, sharex)
#     949         record_name,
#     950         sig_units,
# --> 951     ) = _get_wfdb_plot_items(
#     952         record=record, annotation=annotation, plot_sym=plot_sym
#     953     )
#
# /usr/local/lib/python3.10/dist-packages/wfdb/plot/plot.py in _get_wfdb_plot_items(record, annotation, plot_sym)
#    1060     # Get record attributes
#    1061     if record:
# -> 1062         if record.e_p_signal is not None:
#    1063             signal = record.e_p_signal
#    1064             n_sig = len(signal)
#
# AttributeError: 'tuple' object has no attribute 'e_p_signal'
